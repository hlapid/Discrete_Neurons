# %%
from IPython.display import FileLink, FileLinks

# %%
FileLinks('.', recursive=True)
# Out:
# ./
#   cmd_log.txt
#   DefaultComponent.bat
#   DefaultConfig.cg_info
#   Discrete Neurons iPython Notebook.ipynb
#   discreteNeurons.py
#   discreteNeurons.pyc
#   dis_neuron_log.csv
#   error.txt
#   files.lst
#   MainDefaultComponent.class
#   MainDefaultComponent.java
#   paramsReader.py
#   smarterReader.py
#   smarterReaderDifferentConfigs.py
#   smarterReaderOneNeuron.py
#   testing.csv
#   Untitled.ipynb
#   weightScriptByTypes.py
# .\.ipynb_checkpoints/
#   Discrete Neurons iPython Notebook-checkpoint.ipynb
#   Untitled-checkpoint.ipynb
# .\Default/
#   Default_pkgClass.class
#   Default_pkgClass.java
#   evExternalTrig.class
#   evExternalTrig.java
#   evNoAP.class
#   evNoAP.java
#   evNoMoreTrigs.class
#   evNoMoreTrigs.java
#   evSendAP.class
#   evSendAP.java
#   evSendTrig.class
#   evSendTrig.java
#   evTick.class
#   evTick.java
#   evTick_Gen_Neuron_Event.class
#   evTrig.class
#   evTrig.java
#   EX_IN$Animate.class
#   EX_IN$Reactive.class
#   EX_IN.class
# ...
